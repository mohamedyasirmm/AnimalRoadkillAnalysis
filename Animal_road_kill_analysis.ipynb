# %% [markdown]
# <h1>Animal Roadkill Analysis for the City of Cincinnati</h1>
# <br><i>Author:</i><b> Mohamed Yasir</b><br><i>Email:</i> mohamedyasirmm@gmail.com

# %%
import pandas as pd
import inflect
from autocorrect import Speller
from fuzzywuzzy import fuzz

p = inflect.engine()

# %%
data=pd.read_csv("./roadkill.csv") ##reading roadkill dataset
lookdata=pd.read_csv("./animal.csv") ##List of animal names in north america
stopword_file=open("./stopwords.txt", encoding="utf8")

# %%
##omitting stop words from the description to save time and memory during the search
stopwords=set()
for line in stopword_file:
    for word in line.split():
        stopwords.add(word.strip())

# %%
data=pd.DataFrame(data)
ld=pd.DataFrame(lookdata)
len(data)
# Out:
# 14763

# %%
ld_lst=ld["Animals"].tolist() ##converting the animal name excel file into a list of animal names

# %%
for i in range(0,len(ld_lst)):
    ld_lst[i]=ld_lst[i].lower() ##Standardizing all the animals by converting in to lower case

# %%
data["animal_name"]="" #creating new column to insert animal names

# %%
spell=Speller()

# %% [markdown]
# Problem: Description column in this dataset contains the incident details. but it also contains which animal has died in that particular event. For analysis and visualization purposes, we need only the animal name from the description of the each incident. Also, the description column contains lot of misspelled animal names, which cannot be extracted by simply doing a list search.

# %%
for i in range(0,len(data)):
    for word in data["DESCRIPTION"][i].split(): ##Splitting the description in to words and removing any special characters in it
        word = word.lower().strip()
        word = word.replace(".","")
        word = word.replace(",","")
        word = word.replace("\"","")
        word = word.replace("/","")
        word = word.replace("?","")
        word = word.replace("-","")
        if word not in stopwords:    ##checking whether the word is not in the stopword list to skip the stopwords.
            if p.singular_noun(word):    ##Converting plural words in to singular words
                word=p.singular_noun(word)
            if spell(word) not in ld_lst:  ##Since the description values contains lot of spelling mistakes, First checking the spell checked word not in the animal name list.
                for j in range(0, len(ld_lst)):
                    if fuzz.ratio(word,ld_lst[j])==100: ##Applying Levenshtein Distance method to identify the mistyped animal names in the description by comparing with the list animal names
                        data["animal_name"][i]=ld_lst[j]
                        break;
            else:
                data["animal_name"][i]=spell(word)  ##if the spell checked word is in the animal name list then that word will get added to the column
# Out:
# <ipython-input-32-46438eb7525f>:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["animal_name"][i]=spell(word)  ##if the spell checked word is in the animal name list then that word will get added to the column
# <ipython-input-32-46438eb7525f>:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["animal_name"][i]=ld_lst[j]

# %%
data.head(50)
# Out:
#      SERVICE_NAME SERVICE_CODE  \
# 0   "Dead animal"     "DAPUB1"
# 1   "Dead animal"     "DAPUB1"
# 2   "Dead animal"     "DAPUB1"
# 3   "Dead animal"     "DAPUB1"
# 4   "Dead animal"     "DAPUB1"
# 5   "Dead animal"     "DAPUB1"
# 6   "Dead animal"     "DAPUB1"
# 7   "Dead animal"     "DAPUB1"
# 8   "Dead animal"     "DAPUB1"
# 9   "Dead animal"     "DAPUB1"
# 10  "Dead animal"     "DAPUB1"
# 11  "Dead animal"     "DAPUB1"
# 12  "Dead animal"     "DAPUB1"
# 13  "Dead animal"     "DAPUB1"
# 14  "Dead animal"     "DAPUB1"
# 15  "Dead animal"     "DAPUB1"
# 16  "Dead animal"     "DAPUB1"
# 17  "Dead animal"     "DAPUB1"
# 18  "Dead animal"     "DAPUB1"
# 19  "Dead animal"     "DAPUB1"
# 20  "Dead animal"     "DAPUB1"
# 21  "Dead animal"     "DAPUB1"
# 22  "Dead animal"     "DAPUB1"
# 23  "Dead animal"     "DAPUB1"
# 24  "Dead animal"     "DAPUB1"
# 25  "Dead animal"     "DAPUB1"
# 26  "Dead animal"     "DAPUB1"
# 27  "Dead animal"     "DAPUB1"
# 28  "Dead animal"     "DAPUB1"
# 29  "Dead animal"     "DAPUB1"
# 30  "Dead animal"     "DAPUB1"
# 31  "Dead animal"     "DAPUB1"
# 32  "Dead animal"     "DAPUB1"
# 33  "Dead animal"     "DAPUB1"
# 34  "Dead animal"     "DAPUB1"
# 35  "Dead animal"     "DAPUB1"
# 36  "Dead animal"     "DAPUB1"
# 37  "Dead animal"     "DAPUB1"
# 38  "Dead animal"     "DAPUB1"
# 39  "Dead animal"     "DAPUB1"
# 40  "Dead animal"     "DAPUB1"
# 41  "Dead animal"     "DAPUB1"
# 42  "Dead animal"     "DAPUB1"
# 43  "Dead animal"     "DAPUB1"
# 44  "Dead animal"     "DAPUB1"
# 45  "Dead animal"     "DAPUB1"
# 46  "Dead animal"     "DAPUB1"
# 47  "Dead animal"     "DAPUB1"
# 48  "Dead animal"     "DAPUB1"
# 49  "Dead animal"     "DAPUB1"
#
#                                           DESCRIPTION    REQUESTED_DATETIME  \
# 0   "dead deer - by save alot Called states that i...  2019-12-16T11:39:00Z
# 1   "Request entered through the Web. Refer to Int...  2019-10-28T10:35:00Z
# 2                            "DEAD RACCOON IN STREET"  2019-10-28T11:06:00Z
# 3                                     "DEAD  RACCOON"  2019-10-28T09:04:00Z
# 4   "Request entered through the Web. Refer to Int...  2019-10-25T17:47:00Z
# 5   "Request entered through the Web. Refer to Int...  2019-10-25T00:57:00Z
# 6                                      "DEAD RACCOON"  2019-10-28T09:11:00Z
# 7                               "COLLECTED DEAD DEER"  2020-03-17T09:41:00Z
# 8                                     "DEAD  RACCOON"  2019-10-28T09:04:00Z
# 9   "Request entered through the Web. Refer to Int...  2019-03-25T10:04:00Z
# 10                 "DEAD POSSUM IN MIDDLE OF STREET "  2019-03-25T09:06:00Z
# 11                                      "DEAD ANIMAL"  2019-10-25T08:59:00Z
# 12                                     "DEAD RACCOON"  2019-10-28T12:32:00Z
# 13  "Request entered through the Web. Refer to Int...  2019-03-25T11:10:00Z
# 14       "Per 882, collected dead deer from the road"  2019-10-28T11:34:00Z
# 15                                        "DEAD DEER"  2019-10-28T09:13:00Z
# 16                              "DEAD DEER COLLECTED"  2020-03-17T09:40:00Z
# 17                                      "2 DEAD DOGS"  2019-10-25T10:08:00Z
# 18                             "DEAD RACCOON AT CURB"  2019-03-25T12:51:00Z
# 19  "Request entered through the Web. Refer to Int...  2019-10-25T17:56:00Z
# 20  "Request entered through the Web. Refer to Int...  2019-10-25T12:56:00Z
# 21  "Request entered through the Web. Refer to Int...  2019-10-28T11:19:00Z
# 22  "Request entered through the Web. Refer to Int...  2019-10-24T14:33:00Z
# 23  "Request entered through the Web. Refer to Int...  2019-10-25T16:06:00Z
# 24            "DEAD CAT AT CORNER OF FLORIDA & CHASE"  2019-10-29T12:34:00Z
# 25  "Request entered through the Web. Refer to Int...  2019-10-29T09:02:00Z
# 26  "UNIDENTIFIED DEAD ANIMAL ON SIDEWALK AT SCHOO...  2019-03-26T16:23:00Z
# 27            "DEAD DEER AT MITCHELL & SPRING GROVE "  2019-03-27T07:42:00Z
# 28  "Request entered through the Web. Refer to Int...  2019-10-29T11:21:00Z
# 29                      "DEAD DOG IN BOX AT THE CURB"  2020-03-18T13:21:00Z
# 30                                      "Dead Animal"  2020-03-19T08:40:00Z
# 31                                "(2) DEAD RACCOONS"  2020-08-10T09:18:00Z
# 32               "2000 Block of Woodrow dead animal "  2020-03-19T08:25:00Z
# 33  "Request entered through the Web. Refer to Int...  2020-03-18T15:22:00Z
# 34                                        "DEAD DEER"  2020-03-18T09:10:00Z
# 35                                           "racoon"  2020-03-19T07:21:00Z
# 36  "Dead Raccoon a few feet from this address on ...  2019-03-28T09:33:00Z
# 37  "Request entered through the Web. Refer to Int...  2019-03-27T11:55:00Z
# 38                        "DEAD RACOON IN THE STREET"  2019-10-29T07:08:00Z
# 39  "Request entered through the Web. Refer to Int...  2019-10-30T10:23:00Z
# 40                        "DEAD RACOON IN THE STREET"  2019-10-30T08:45:00Z
# 41                                        "DEAD DEER"  2019-10-30T07:03:00Z
# 42  "Request entered through the Web. Refer to Int...  2019-10-28T20:13:00Z
# 43  "Request entered through the Web. Refer to Int...  2019-10-29T04:51:00Z
# 44                "DEAD RACOON ON SIDE OF THE STREET"  2019-03-27T12:21:00Z
# 45                                        "DEAD DEER"  2019-10-30T12:15:00Z
# 46                                                " "  2019-10-29T14:54:00Z
# 47  "dead cat on sidewalk - partially covered with...  2019-03-27T13:30:00Z
# 48  "DEAD POSSUM AT CURB WRAPPED IN TOWEL THE 1ST ...  2019-03-26T14:17:00Z
# 49  "Email - There is a dead raccoon at 2707 Hackb...  2019-10-28T16:11:00Z
#
#                                               ADDRESS   LATITUDE  LONGITUDE  \
# 0          "HARRISON AV & MCHENRY AV - GJ0908435179 "  39.140706 -84.580759
# 1              "3279 LINWOOD AV, CINC - GJ2240434003"  39.126825 -84.427154
# 2                      "3462 VINE ST - GJ1511035745 "  39.144336 -84.510915
# 3                     "7138 RIVER RD - FJ9871332835 "  39.122035 -84.701350
# 4             "1176 CORONADO AV, CINC - GJ0742932470"  39.116721 -84.600705
# 5                "663 RIDDLE RD, CINC - GJ1355934761"  39.135867 -84.529140
# 6               "BANK ST & KINDEL AV - GJ1336732949 "  39.119598 -84.531939
# 7   "MCFARLAN WOODS DR & WESTWOOD NORTHERN BLVD - ...  39.153444 -84.590776
# 8                     "3984 RIVER RD - GJ0700528023 "  39.076776 -84.606975
# 9              "4815 WHETSEL AV, CINC - GJ2521437664"  39.159061 -84.393468
# 10                      "1238 1ST AV - GJ0932832390 "  39.115543 -84.578798
# 11                "4695 RAPID RUN RD - GJ0799231928 "  39.111703 -84.594382
# 12            "VINE ST & JUERGENS AV - GJ1517036474 "  39.150888 -84.509984
# 13           "1255 HOLLYWOOD AV, CINC - GJ1263042737"  39.207905 -84.537378
# 14                 "2399 HARRISON AV - GJ0920534993 "  39.139005 -84.579418
# 15  "RED BANK EXWY & HETZEL ST - GJ2412337516 PRIV...  39.158008 -84.406132
# 16                  "3424 BEEKMAN ST - GJ1166036364 "  39.150754 -84.550599
# 17                  "2818 GLENWAY AV - GJ1122032126 "  39.112713 -84.557013
# 18                     "6405 MEIS AV - GJ1127742867 "  39.209395 -84.553003
# 19                    "2121 SPRING GROVE AV, CINC - "  39.120878 -84.536778
# 20                        "3018 HARRISON AV, CINC - "  39.148650 -84.598178
# 21                          "2650 LEHMAN RD, CINC - "  39.117405 -84.550557
# 22        "3008 LOSANTIVILLE AV, CINC - GJ2195940360"  39.184169 -84.430198
# 23             "7501 GRACELY DR, CINC - FJ9829033715"  39.129849 -84.706129
# 24            "FLORIDA AV & CHASE AV - GJ1180337920 "  39.164726 -84.548460
# 25            "502 HAWTHORNE AV, CINC - GJ1077130629"  39.099347 -84.562660
# 26            "CEDAR AV & LANTANA AV - GJ1225341661 "  39.198298 -84.542090
# 27  "SPRING GROVE AV & W MITCHELL AV - GJ1479138176 "  39.166305 -84.513826
# 28               "3908 W 8TH ST, CINC - GJ0926031426"  39.106886 -84.579878
# 29                  "4020 HEYWARD ST - GJ0924833147 "  39.122377 -84.579483
# 30                 "3160 BOUDINOT AV - GJ0710635352 "  39.142741 -84.603574
# 31            "WARSAW AV & WILDER AV - GJ1143331403 "  39.106145 -84.554776
# 32                     "1919 GEST ST - GJ1191431574 "  39.107568 -84.549157
# 33            "5100 COLERAIN AV, CINC - GJ1017439720"  39.181339 -84.566729
# 34        "PRESIDENT DR & FARADAY RD - GJ1072936537 "  39.152538 -84.561314
# 35         "KEMPER LN & RIVERSIDE DR - GJ1726632500 "  39.114587 -84.487026
# 36                 "2262 HARRISON AV - GJ0958734629 "  39.135641 -84.575108
# 37               "3423 W 8TH ST, CINC - GJ1036031295"  39.105440 -84.567199
# 38                "1809 WYNNEWOOD LN - GJ1974842758 "  39.206314 -84.455018
# 39            "1528 TEAKWOOD AV, CINC - GJ1193342654"  39.207323 -84.545469
# 40                  "4932 GLENWAY AV - GJ0751332786 "  39.119542 -84.599647
# 41                "6414 FAIRHURST AV - GJ2133940776 "  39.188069 -84.437254
# 42                "958 DELHI AV, CINC - GJ0967930089"  39.094641 -84.575396
# 43             "3279 LINWOOD AV, CINC - GJ2240434003"  39.126825 -84.427154
# 44                  "2945 LISCHER AV - GJ0759235535 "  39.144272 -84.597896
# 45                  "5015 MADISON RD - GJ2380937894 "  39.161496 -84.409641
# 46                    "1700 PULTE ST - GJ1172634777 "  39.136455 -84.550330
# 47                  "2522 HEMLOCK ST - GJ1667433853 "  39.126924 -84.493433
# 48             "5425 WINTON RIDGE LN - GJ1414740683 "  39.189033 -84.520480
# 49                "2707 HACKBERRY ST - GJ1824734084 "  39.128601 -84.475173
#
#    animal_name
# 0         deer
# 1
# 2      raccoon
# 3      raccoon
# 4
# 5
# 6      raccoon
# 7         deer
# 8      raccoon
# 9
# 10      possum
# 11
# 12     raccoon
# 13
# 14        deer
# 15        deer
# 16        deer
# 17         dog
# 18     raccoon
# 19
# 20
# 21
# 22
# 23
# 24         cat
# 25
# 26
# 27        deer
# 28
# 29         dog
# 30
# 31     raccoon
# 32
# 33
# 34        deer
# 35     raccoon
# 36     raccoon
# 37
# 38     raccoon
# 39
# 40     raccoon
# 41        deer
# 42
# 43
# 44     raccoon
# 45        deer
# 46
# 47         cat
# 48      possum
# 49     raccoon

# %% [markdown]
# <b> You can now see that the last column contains animal name that are mentioned in the description column </b>

# %%
data.to_excel (r'./roadkill_cleaned_new.xlsx', index = False, header=True)

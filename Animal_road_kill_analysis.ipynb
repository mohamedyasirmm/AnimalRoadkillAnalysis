# %% [markdown]
# <h1>Animal Roadkill Analysis for the City of Cincinnati</h1>
# <br><i>Author:</i><b> Mohamed Yasir</b><br><i>Email:</i> mohamedyasirmm@gmail.com

# %%
import pandas as pd
import inflect
from autocorrect import Speller
from fuzzywuzzy import fuzz

p = inflect.engine()
# Out:
# C:\Users\yasir\miniconda3\lib\site-packages\fuzzywuzzy\fuzz.py:11: UserWarning: Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning
#   warnings.warn('Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning')

# %%
data = pd.read_excel("./roadkills.xlsx",
     engine='openpyxl',
) ##reading roadkill dataset
lookdata=pd.read_csv("./animal.csv") ##List of animal names in north america
stopword_file=open("./stopwords.txt", encoding="utf8")

# %%
##omitting stop words from the description to save time and memory during the search
stopwords=set()
for line in stopword_file:
    for word in line.split():
        stopwords.add(word.strip())

# %%
data=pd.DataFrame(data)
ld=pd.DataFrame(lookdata)
len(data)
# Out:
# 16895

# %%
ld_lst=ld["Animals"].tolist() ##converting the animal name excel file into a list of animal names

# %%
for i in range(0,len(ld_lst)):
    ld_lst[i]=ld_lst[i].lower() ##Standardizing all the animals by converting in to lower case

# %%
data["animal_name"]="" #creating new column to insert animal names

# %%
spell=Speller()

# %% [markdown]
# Problem: Description column in this dataset contains the incident details. but it also contains which animal has died in that particular event. For analysis and visualization purposes, we need only the animal name from the description of the each incident. Also, the description column contains lot of misspelled animal names, which cannot be extracted by simply doing a list search.

# %%
for i in range(0,len(data)):
    for word in data["DESCRIPTION"][i].split(): ##Splitting the description in to words and removing any special characters in it
        word = word.lower().strip()
        word = word.replace(".","")
        word = word.replace(",","")
        word = word.replace("\"","")
        word = word.replace("/","")
        word = word.replace("?","")
        word = word.replace("-","")
        if word not in stopwords:    ##checking whether the word is not in the stopword list to skip the stopwords.
            if p.singular_noun(word):    ##Converting plural words in to singular words
                word=p.singular_noun(word)
            if spell(word) not in ld_lst:  ##Since the description values contains lot of spelling mistakes, First checking the spell checked word not in the animal name list.
                for j in range(0, len(ld_lst)):
                    if fuzz.ratio(word,ld_lst[j])==100: ##Applying Levenshtein Distance method to identify the mistyped animal names in the description by comparing with the list animal names
                        data["animal_name"][i]=ld_lst[j]
                        break;
            else:
                data["animal_name"][i]=spell(word)  ##if the spell checked word is in the animal name list then that word will get added to the column
# Out:
# <ipython-input-21-46438eb7525f>:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["animal_name"][i]=spell(word)  ##if the spell checked word is in the animal name list then that word will get added to the column
# <ipython-input-21-46438eb7525f>:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["animal_name"][i]=ld_lst[j]

# %%
data.head(50)
# Out:
#      SERVICE_NAME SERVICE_CODE  \
# 0   "Dead animal"     "DAPUB1"
# 1   "Dead animal"     "DAPUB1"
# 2   "Dead animal"     "DAPUB1"
# 3   "Dead animal"     "DAPUB1"
# 4   "Dead animal"     "DAPUB1"
# 5   "Dead animal"     "DAPUB1"
# 6   "Dead animal"     "DAPUB1"
# 7   "Dead animal"     "DAPUB1"
# 8   "Dead animal"     "DAPUB1"
# 9   "Dead animal"     "DAPUB1"
# 10  "Dead animal"     "DAPUB1"
# 11  "Dead animal"     "DAPUB1"
# 12  "Dead animal"     "DAPUB1"
# 13  "Dead animal"     "DAPUB1"
# 14  "Dead animal"     "DAPUB1"
# 15  "Dead animal"     "DAPUB1"
# 16  "Dead animal"     "DAPUB1"
# 17  "Dead animal"     "DAPUB1"
# 18  "Dead animal"     "DAPUB1"
# 19  "Dead animal"     "DAPUB1"
# 20  "Dead animal"     "DAPUB1"
# 21  "Dead animal"     "DAPUB1"
# 22  "Dead animal"     "DAPUB1"
# 23  "Dead animal"     "DAPUB1"
# 24  "Dead animal"     "DAPUB1"
# 25  "Dead animal"     "DAPUB1"
# 26  "Dead animal"     "DAPUB1"
# 27  "Dead animal"     "DAPUB1"
# 28  "Dead animal"     "DAPUB1"
# 29  "Dead animal"     "DAPUB1"
# 30  "Dead animal"     "DAPUB1"
# 31  "Dead animal"     "DAPUB1"
# 32  "Dead animal"     "DAPUB1"
# 33  "Dead animal"     "DAPUB1"
# 34  "Dead animal"     "DAPUB1"
# 35  "Dead animal"     "DAPUB1"
# 36  "Dead animal"     "DAPUB1"
# 37  "Dead animal"     "DAPUB1"
# 38  "Dead animal"     "DAPUB1"
# 39  "Dead animal"     "DAPUB1"
# 40  "Dead animal"     "DAPUB1"
# 41  "Dead animal"     "DAPUB1"
# 42  "Dead animal"     "DAPUB1"
# 43  "Dead animal"     "DAPUB1"
# 44  "Dead animal"     "DAPUB1"
# 45  "Dead animal"     "DAPUB1"
# 46  "Dead animal"     "DAPUB1"
# 47  "Dead animal"     "DAPUB1"
# 48  "Dead animal"     "DAPUB1"
# 49  "Dead animal"     "DAPUB1"
#
#                                           DESCRIPTION REQUESTED_DATETIME  \
# 0                                         "DEAD DEER"         2021-12-06
# 1   "DEAD CAT - BLACK IN COLOR - AT THE CURB IN GR...         2021-12-06
# 2                             "DEAD DEER AT THE CURB"         2021-12-06
# 3   "Request entered through the Web. Refer to Int...         2021-12-06
# 4   "Request entered through the Web. Refer to Int...         2021-12-06
# 5   "Request entered through the Web. Refer to Int...         2021-12-04
# 6                                          "dead cat"         2021-12-03
# 7   "Request entered through the Web. Refer to Int...         2021-12-03
# 8   "Request entered through the Web. Refer to Int...         2021-12-03
# 9              "DEAD DOG IN THE STREET NEAR THE CURB"         2021-12-02
# 10                                        "Dead cat."         2021-12-02
# 11  "Request entered through the Web. Refer to Int...         2021-12-01
# 12  "(2) DEAD DOGS EASTBOUND OF NORWOOD LATERAL\n1...         2021-12-01
# 13      "DEAD ANIMAL - RACOON INSIDE OF TRASH TOTER "         2021-12-01
# 14                            "DEAD DEER AT THE CURB"         2021-12-01
# 15       "DEAD CAT\nACROSS THE STREET AT THE CURB - "         2021-12-01
# 16                                 "dead racoon/cat "         2021-11-30
# 17  "Dead cat smashed into a pile in the road. Its...         2021-12-01
# 18  "Request entered through the Web. Refer to Int...         2021-11-30
# 19                                  "RAT ON SIDEWALK"         2021-11-30
# 20                                              "DOG"         2021-11-30
# 21                        "DEAD SQUIRREL AT THE CURB"         2021-11-30
# 22  "Request entered through the Web. Refer to Int...         2021-11-30
# 23  "Request entered through the Web. Refer to Int...         2021-11-29
# 24  "Request entered through the Web. Refer to Int...         2021-11-29
# 25  "Dead dog on side walk in front of a daycare.\...         2021-11-29
# 26            "DEAD RACOON ON MONTICELLO AT THE CURB"         2021-11-29
# 27  "IN FRONT OF BEIGE BUILDING( SIGN SAYS MARYS D...         2021-11-29
# 28  "Request entered through the Web. Refer to Int...         2021-11-28
# 29                                "DEER BY THE WALL "         2021-11-29
# 30                       "DEAD SQUIREL IN THE STREET"         2021-11-18
# 31  "Request entered through the Web. Refer to Int...         2021-11-22
# 32                             "DEAD DOG AT THE CURB"         2021-11-17
# 33  "Request entered through the Web. Refer to Int...         2021-11-26
# 34                           "cat in middle of lane "         2021-11-22
# 35                                        "DEAD CAT "         2021-11-22
# 36  "ON GLENWAY AVE \nINBETWEEN MCPHERSON AVE AND ...         2021-11-22
# 37      "DEAD DEER IN WESTBOUND LN OF COLUMBIA PKWY "         2021-11-24
# 38  "Request entered through the Web. Refer to Int...         2021-11-20
# 39  "Request entered through the Web. Refer to Int...         2021-11-24
# 40                      "LARGE DEAD DEER IN ROADWAY "         2021-11-24
# 41          "DEAD CAT AT THE CORNER ARGUS & GRAYVIEW"         2021-11-19
# 42                           "DEAD CAT IN THE STREET"         2021-11-19
# 43                                                " "         2021-11-19
# 44                                                " "         2021-11-16
# 45                                        "Dead deer"         2021-11-16
# 46       "AT E 562 & READING DEAD DOG IN THE MEDIAN "         2021-11-23
# 47  "Near the intersection of Girard Ave and Losan...         2021-11-19
# 48                               "DEAD GRAY PITBULL "         2021-11-19
# 49  "dog between two parked cars on reading rd bet...         2021-11-19
#
#                                           ADDRESS   LATITUDE  LONGITUDE  \
# 0                  "3815 ERIE AV - GJ2383436218 "  39.146401 -84.409901
# 1         "WARSAW AV & CARSON AV - GJ0978431964 "  39.111600 -84.573658
# 2                 "5520 KIRBY AV - GJ0991241071 "  39.193560 -84.569357
# 3        "3693 GROVEDALE PL, CINC - GJ2041635872"  39.144157 -84.449516
# 4        "3693 GROVEDALE PL, CINC - GJ2041635872"  39.144157 -84.449516
# 5        "4904 RAPID RUN RD, CINC - GJ0720031882"  39.111485 -84.603545
# 6                  "701 DELHI AV - GJ1014329643 "  39.090613 -84.570224
# 7        "4922 RAPID RUN RD, CINC - GJ0716931948"  39.112086 -84.603880
# 8         "812 FAIRBANKS AV, CINC - GJ1025431405"  39.106457 -84.568395
# 9        "SEYMOUR AV & HIRSCH DR - GJ1929240635 "  39.187316 -84.460982
# 10          "3748 ST LAWRENCE AV - GJ0970831872 "  39.110788 -84.574558
# 11        "5039 ANDERSON PL, CINC - GJ2470238021"  39.162408 -84.399252
# 12              "4760 PADDOCK RD - GJ1789438991 "  39.172873 -84.477684
# 13            "2871 PINERIDGE AV - GJ2136034643 "  39.132856 -84.439015
# 14          "3059 SPENCERHILL LN - GJ2174334091 "  39.127789 -84.434771
# 15             "2700 HARRISON AV - GJ0827935244 "  39.141486 -84.590040
# 16          "1225 W GALBRAITH RD - GJ1298543642 "  39.215954 -84.532994
# 17  "2227 WESTWOOD NORTHERN BLVD - GJ1008635715 "  39.145299 -84.569009
# 18                     "4998 KELLOGG AV, CINC - "  39.078481 -84.422472
# 19                 "701 BROADWAY - GJ1554731365 "  39.104803 -84.507250
# 20              "7329 READING RD - GJ1937341602 "  39.195999 -84.459735
# 21           "1102 EGAN HILLS DR - GJ1769238043 "  39.164388 -84.480324
# 22           "1024 SETON AV, CINC - GJ0956431909"  39.111162 -84.576215
# 23    "3907 SPRING GROVE AV, CINC - GJ1248437093"  39.157127 -84.540827
# 24        "5000 COLERAIN AV, CINC - GJ1064639275"  39.177213 -84.561417
# 25              "3559 READING RD - GJ1688236046 "  39.146611 -84.490323
# 26              "6060 BELMONT AV - GJ1054441846 "  39.200385 -84.561804
# 27       "WARSAW AV & GLENWAY AV - GJ0958032219 "  39.113941 -84.575938
# 28        "5000 COLERAIN AV, CINC - GJ1064639275"  39.177213 -84.561417
# 29   "COLUMBIA PKWY & AUDUBON ST - GJ2020633548 "  39.123283 -84.452710
# 30               "2700 EUCLID AV - GJ1544334205 "  39.130390 -84.507551
# 31            "7505 VINE ST, CINC - GJ1797441908"  39.199113 -84.475811
# 32         "2212 W NORTH BEND RD - GJ1035841860 "  39.200553 -84.563944
# 33          "6234 GIRARD AV, CINC - GJ2142040533"  39.185859 -84.436377
# 34        "10 CLINTON SPRINGS LN - GJ1552337316 "  39.158381 -84.505637
# 35              "3643 GLENWAY AV - GJ0988132210 "  39.113794 -84.572457
# 36    "GLENWAY AV & MCPHERSON AV - GJ1008232214 "  39.113775 -84.570137
# 37     "COLUMBIA PKWY & DELTA AV - GJ2138332908 "  39.117230 -84.439321
# 38       "4910 GLENSHADE AV, CINC - GJ2569737740"  39.159622 -84.387854
# 39                     "3559 READING RD, CINC - "  39.146611 -84.490323
# 40          "3281 OBSERVATORY AV - GJ2271235119 "  39.136793 -84.423238
# 41                "5750 ARGUS RD - GJ1284741321 "  39.195096 -84.535323
# 42               "4329 CAPPEL DR - GJ0799331173 "  39.104904 -84.594603
# 43              "6250 ORCHARD LN - GJ2284140917 "  39.188949 -84.419831
# 44              "125 WILDWOOD ST - GJ1825242856 "  39.207576 -84.472293
# 45             "3648 WOODFORD RD - GJ2350539986 "  39.180407 -84.412462
# 46              "4760 PADDOCK RD - GJ1789438991 "  39.172873 -84.477684
# 47  "GIRARD AV & LOSANTIVILLE AV - GJ2141140698 "  39.187347 -84.436447
# 48            "2775 LAFEUILLE AV - GJ0820134515 "  39.134949 -84.591161
# 49              "3602 READING RD - GJ1703436178 "  39.147759 -84.488528
#
#    animal_name
# 0         deer
# 1          cat
# 2         deer
# 3
# 4
# 5
# 6          cat
# 7
# 8
# 9          dog
# 10         cat
# 11
# 12         dog
# 13     raccoon
# 14        deer
# 15         cat
# 16
# 17         cat
# 18
# 19         rat
# 20         dog
# 21    squirrel
# 22
# 23
# 24
# 25         dog
# 26     raccoon
# 27         cat
# 28
# 29        deer
# 30    squirrel
# 31
# 32         dog
# 33
# 34         cat
# 35         cat
# 36         cat
# 37        deer
# 38
# 39
# 40        deer
# 41         cat
# 42         cat
# 43
# 44
# 45        deer
# 46         dog
# 47        deer
# 48
# 49         dog

# %% [markdown]
# <b> You can now see that the last column contains animal name that are mentioned in the description column </b>

# %%
data.to_excel (r'./roadkill_cleaned_new_2023.xlsx', index = False, header=True)
